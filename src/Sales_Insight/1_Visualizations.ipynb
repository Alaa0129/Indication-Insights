# %%
# SalesInsightsPreprocessing
from PreprocessingScript import *
# Out:
# c:\Users\Josef\OneDrive\Skrivebord\ITU\3. semester\Big Data\Code\Indication-Insights\src\Sales_Insight\PreprocessingScript.py:18: SyntaxWarning: invalid escape sequence '\s'
#   pharDf = pd.read_csv('data_processed\sales_insights_pharmacy_cleaned.csv', delimiter=',')
# c:\Users\Josef\OneDrive\Skrivebord\ITU\3. semester\Big Data\Code\Indication-Insights\src\Sales_Insight\PreprocessingScript.py:19: SyntaxWarning: invalid escape sequence '\s'
#   hospDf = pd.read_csv('data_processed\sales_insights_hospital_cleaned.csv', delimiter=',')
# 7282
# 4724
# Index(['Account Description', 'Size', 'Size Numeric', 'Strength (mg)',
#        'WHO ATC 5 Code', 'Volume', 'Value', 'Year Month (after 2000)',
#        'Year (after 2000)', 'Month', 'Region_Færøerne', 'Region_Hovedstaden',
#        'Region_Midtjylland', 'Region_Nordjylland', 'Region_Sjælland',
#        'Region_Syddanmark', 'Product_Cimzia', 'Product_Inflectra',
#        'Product_Remicade', 'Product_Remsima', 'Product_Stelara',
# ...

# %% [markdown]
# #### Draw stacked column chart of total sales of Stelara in hospitals and pharmacies btw 2010 and 2019

# %%
# Plot the stacked column chart
pivot_df_stelara.plot(kind='bar', stacked=True, figsize=(25, 10))
plt.xticks(rotation=90)
plt.title('Total Sales of Stelara in hospitals, pharmacies, and sickhouses from 2010 to 2019')
plt.ylabel('Volume')
plt.xlabel('Year Month (after 2000) in Datetime')
plt.legend(title='Type')
plt.show()

# %% [markdown]
# #### Draw stacked column chart of total sales of Cimzia in hospitals and pharmacies btw 2010 and 2019

# %%
# Plot the stacked column chart
pivot_df_cimzia.plot(kind='bar', stacked=True, figsize=(25, 10))
plt.xticks(rotation=90)
plt.title('Total Sales of Cimzia in hospitals, pharmacies, and sickhouses from 2010 to 2019')
plt.ylabel('Volume')
plt.xlabel('Year Month (after 2000)')
plt.legend(title='Type')
plt.show()

# %% [markdown]
# #### Draw stacked column chart of total sales of Inflectra in hospitals and pharmacies btw 2010 and 2019

# %%
# Plot the stacked column chart
pivot_df_inflectra.plot(kind='bar', stacked=True, figsize=(25, 10))
plt.xticks(rotation=90)
plt.title('Total Sales of Inflectra in hospitals, pharmacies, and sickhouses from 2010 to 2019')
plt.ylabel('Volume')
plt.xlabel('Year Month (after 2000)')
plt.legend(title='Type')
plt.show()

# %% [markdown]
# #### Draw stacked column chart of total sales of Remicade in hospitals and pharmacies btw 2010 and 2019

# %%
# Plot the stacked column chart
pivot_df_remicade.plot(kind='bar', stacked=True, figsize=(25, 10))
plt.xticks(rotation=90)
plt.title('Total Sales of Remicade in hospitals, pharmacies, and sickhouses from 2010 to 2019')
plt.ylabel('Volume')
plt.xlabel('Year Month (after 2000)')
plt.legend(title='Type')
plt.show()

# %% [markdown]
# #### Draw stacked column chart of total sales of Remsima in hospitals and pharmacies btw 2010 and 2019

# %%
# Plot the stacked column chart
pivot_df_remsima.plot(kind='bar', stacked=True, figsize=(25, 10))
plt.xticks(rotation=90)
plt.title('Total Sales of Remsima in hospitals, pharmacies, and sickhouses from 2010 to 2019')
plt.ylabel('Volume')
plt.xlabel('Year Month (after 2000)')
plt.legend(title='Type')
plt.show()

# %% [markdown]
# #### Draw stacked column chart of total sales of Zessly in hospitals and pharmacies btw 2010 and 2019

# %%
# Plot the stacked column chart
pivot_df_zessly.plot(kind='bar', stacked=True, figsize=(25, 10))
plt.xticks(rotation=90)
plt.title('Total Sales of Zessly in hospitals, pharmacies, and sickhouses from 2010 to 2019')
plt.ylabel('Volume')
plt.xlabel('Year Month (after 2000)')
plt.legend(title='Type')
plt.show()

# %% [markdown]
# #### ATC5 code L04AC05 sales over time

# %%
# Pivot the data
pivot_df_zessly = DfYearAndL04AC05SortedWithTypes.pivot_table(index='Year Month (after 2000)', columns='Type', values='Volume', aggfunc='sum').fillna(0)

# Plot the stacked column chart
pivot_df_zessly.plot(kind='bar', stacked=True, figsize=(25, 10))
plt.xticks(rotation=90)
plt.title('Total Sales of L04AC05 products in hospitals, pharmacies, and sickhouses from 2010 to 2019')
plt.ylabel('Volume')
plt.xlabel('Year Month (after 2000)')
plt.legend(title='Type')
plt.show()

# %% [markdown]
# #### Draw scatter, line, bubble, or combo plot to show relationship between sold stelara over time between 2010 and 2019 in central pharmacy

# %%
# Plot the median values in a line plot
sns.set_theme(style="whitegrid")
plt.figure(figsize=(30, 6))
sns.lineplot(x='Year Month (after 2000) in Datetime', y='Volume', data=meanValaues)
plt.xticks(rotation=90)
plt.title('Average Sales of Stelara in the central pharmacy by month btw 2010 and 2019')
plt.show()

# %% [markdown]
# #### Show correlation between Volume and other features

# %%
m2 = m2.drop('Value', axis=1)
m2.drop('Volume', axis=1).corrwith(m2.Volume).sort_values().plot(kind='barh', figsize=(15, 10))
# Out:
# <Axes: >

# %% [markdown]
# #### make dataset with product fetaure for pie chart

# %%
mergedHospitalPharmacySickHouseDfYearAndStelaraSorted['Product'] = 'Stelara'
mergedHospitalPharmacySickHouseDfYearAndCimziaSorted['Product'] = 'Cimzia'
mergedHospitalPharmacySickHouseDfYearAndInflectraSorted['Product'] = 'Inflectra'
mergedHospitalPharmacySickHouseDfYearAndRemicadeSorted['Product'] = 'Remicade'
mergedHospitalPharmacySickHouseDfYearAndRemsimaSorted['Product'] = 'Remsima'
mergedHospitalPharmacySickHouseDfYearAndZesslySorted['Product'] = 'Zessly'

mergedHospitalPharmacySickHouseDfYearAndSortedWithproduct = pd.concat([mergedHospitalPharmacySickHouseDfYearAndStelaraSorted, mergedHospitalPharmacySickHouseDfYearAndCimziaSorted, mergedHospitalPharmacySickHouseDfYearAndInflectraSorted, mergedHospitalPharmacySickHouseDfYearAndRemicadeSorted, mergedHospitalPharmacySickHouseDfYearAndRemsimaSorted, mergedHospitalPharmacySickHouseDfYearAndZesslySorted], ignore_index=True)

colors = ['#87CEEB', '#70BFE4', '#5BAFDA', '#469FCE', '#D62728', '#2CA02C']

mergedHospitalPharmacySickHouseDfYearAndSortedWithproduct.groupby(['WHO ATC 5 Code', 'Product']).sum().plot( 
    kind='pie', y='Volume', autopct='%1.0f%%', colors=colors, figsize=(10, 10))

plt.title('Total sales of the products in various ATC 5 codes in hospitals and pharmacies between 2010 and 2019')
# Out:
# Text(0.5, 1.0, 'Total sales of the products in various ATC 5 codes in hospitals and pharmacies between 2010 and 2019')
