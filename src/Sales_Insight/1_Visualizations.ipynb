# %%
# SalesInsightsPreprocessing
from Scripts.PreprocessingScript import *
# Out:
# c:\Users\Josef\OneDrive\Skrivebord\ITU\3. semester\Big Data\Code\Indication-Insights\src\Sales_Insight\Scripts\PreprocessingScript.py:15: SyntaxWarning: invalid escape sequence '\s'
#   pharDf = pd.read_csv('data_processed\sales_insights_pharmacy_cleaned.csv', delimiter=',')
# c:\Users\Josef\OneDrive\Skrivebord\ITU\3. semester\Big Data\Code\Indication-Insights\src\Sales_Insight\Scripts\PreprocessingScript.py:16: SyntaxWarning: invalid escape sequence '\s'
#   hospDf = pd.read_csv('data_processed\sales_insights_hospital_cleaned.csv', delimiter=',')
# 7282
# 4724
# Index(['Account Description', 'Size', 'Size Numeric', 'Strength (mg)',
#        'WHO ATC 5 Code', 'Volume', 'Value', 'Year Month (after 2000)',
#        'Year (after 2000)', 'Month', 'Region_Færøerne', 'Region_Hovedstaden',
#        'Region_Midtjylland', 'Region_Nordjylland', 'Region_Sjælland',
#        'Region_Syddanmark', 'Product_Cimzia', 'Product_Inflectra',
#        'Product_Remicade', 'Product_Remsima', 'Product_Stelara',
#        'Product_Zessly'],
#       dtype='object')
# Index(['Account Description', 'Size', 'Size Numeric', 'Strength (mg)',
#        'WHO ATC 5 Code', 'Volume', 'Value', 'Year Month (after 2000)',
#        'Year (after 2000)', 'Month', 'Region_Hovedstaden',
#        'Region_Midtjylland', 'Region_Nordjylland', 'Region_Sjælland',
#        'Region_Syddanmark', 'Product_Cimzia', 'Product_Inflectra',
#        'Product_Remicade', 'Product_Remsima', 'Product_Stelara',
#        'Product_Zessly'],
#       dtype='object')
# 7282
# 1154
# 6128
# Hospital total sales btw 2010 and 2019 for Stelara:  7621.0
# Pharmacy total sales btw 2010 and 2019 for Stelara:  23815.0
# Hospital total sales btw 2010 and 2019 for Cimzia:  13481.0
# Pharmacy total sales btw 2010 and 2019 for Cimzia:  66583.0
# Hospital total sales btw 2010 and 2019 for Inflectra:  46652.0
# Pharmacy total sales btw 2010 and 2019 for Inflectra:  197095.0
# Hospital total sales btw 2010 and 2019 for Remicade:  59393.0
# Pharmacy total sales btw 2010 and 2019 for Remicade:  367349.0
# Hospital total sales btw 2010 and 2019 for Remsima:  51072.0
# Pharmacy total sales btw 2010 and 2019 for Remsima:  248589.0
# Hospital total sales btw 2010 and 2019 for Zessly:  22290.0
# Pharmacy total sales btw 2010 and 2019 for Zessly:  94974.0
#     Year Month (after 2000) in Datetime  Volume
# 0                               2010-05    12.0
# 1                               2010-06    22.0
# 2                               2010-07    16.0
# 3                               2010-08    12.0
# 4                               2010-09    24.0
# ..                                  ...     ...
# 110                             2019-08    90.0
# 111                             2019-09    51.0
# 112                             2019-10    64.0
# 113                             2019-11    78.0
# 114                             2019-12   113.0
#
# [115 rows x 2 columns]
# 18
# c:\Users\Josef\OneDrive\Skrivebord\ITU\3. semester\Big Data\Code\Indication-Insights\src\Sales_Insight\Scripts\PreprocessingScript.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hospitalDf['Year Month (after 2000) in Datetime'] = pd.to_datetime(hospitalDf['Year Month (after 2000)'].astype(int).astype(str), format='%y%m')
# c:\Users\Josef\OneDrive\Skrivebord\ITU\3. semester\Big Data\Code\Indication-Insights\src\Sales_Insight\Scripts\PreprocessingScript.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pharmacyDf['Year Month (after 2000) in Datetime'] = pd.to_datetime(pharmacyDf['Year Month (after 2000)'].astype(int).astype(str), format='%y%m')
# c:\Users\Josef\OneDrive\Skrivebord\ITU\3. semester\Big Data\Code\Indication-Insights\src\Sales_Insight\Scripts\PreprocessingScript.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hospitalDf['Year Month (after 2000) in Datetime'] = hospitalDf['Year Month (after 2000) in Datetime'].dt.to_period('M')
# c:\Users\Josef\OneDrive\Skrivebord\ITU\3. semester\Big Data\Code\Indication-Insights\src\Sales_Insight\Scripts\PreprocessingScript.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pharmacyDf['Year Month (after 2000) in Datetime'] = pharmacyDf['Year Month (after 2000) in Datetime'].dt.to_period('M')
# c:\Users\Josef\OneDrive\Skrivebord\ITU\3. semester\Big Data\Code\Indication-Insights\src\Sales_Insight\Scripts\PreprocessingScript.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hospitalDf['Year Month (after 2000) in Datetime'] = hospitalDf['Year Month (after 2000) in Datetime'].astype(str)
# c:\Users\Josef\OneDrive\Skrivebord\ITU\3. semester\Big Data\Code\Indication-Insights\src\Sales_Insight\Scripts\PreprocessingScript.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pharmacyDf['Year Month (after 2000) in Datetime'] = pharmacyDf['Year Month (after 2000) in Datetime'].astype(str)
# c:\Users\Josef\OneDrive\Skrivebord\ITU\3. semester\Big Data\Code\Indication-Insights\src\Sales_Insight\Scripts\PreprocessingScript.py:171: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hospitalDfYearAndStelaraSorted['Type'] = 'Hospitals'
# c:\Users\Josef\OneDrive\Skrivebord\ITU\3. semester\Big Data\Code\Indication-Insights\src\Sales_Insight\Scripts\PreprocessingScript.py:172: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PharmacyDfYearAndStelaraSorted['Type'] = 'Pharmacies'
# c:\Users\Josef\OneDrive\Skrivebord\ITU\3. semester\Big Data\Code\Indication-Insights\src\Sales_Insight\Scripts\PreprocessingScript.py:182: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hospitalDfYearAndCimziaSorted['Type'] = 'Hospitals'
# c:\Users\Josef\OneDrive\Skrivebord\ITU\3. semester\Big Data\Code\Indication-Insights\src\Sales_Insight\Scripts\PreprocessingScript.py:183: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PharmacyDfYearAndCimziaSorted['Type'] = 'Pharmacies'
# c:\Users\Josef\OneDrive\Skrivebord\ITU\3. semester\Big Data\Code\Indication-Insights\src\Sales_Insight\Scripts\PreprocessingScript.py:193: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hospitalDfYearAndInflectraSorted['Type'] = 'Hospitals'
# c:\Users\Josef\OneDrive\Skrivebord\ITU\3. semester\Big Data\Code\Indication-Insights\src\Sales_Insight\Scripts\PreprocessingScript.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PharmacyDfYearAndInflectraSorted['Type'] = 'Pharmacies'
# c:\Users\Josef\OneDrive\Skrivebord\ITU\3. semester\Big Data\Code\Indication-Insights\src\Sales_Insight\Scripts\PreprocessingScript.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hospitalDfYearAndRemicadeSorted['Type'] = 'Hospitals'
# c:\Users\Josef\OneDrive\Skrivebord\ITU\3. semester\Big Data\Code\Indication-Insights\src\Sales_Insight\Scripts\PreprocessingScript.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PharmacyDfYearAndRemicadeSorted['Type'] = 'Pharmacies'
# c:\Users\Josef\OneDrive\Skrivebord\ITU\3. semester\Big Data\Code\Indication-Insights\src\Sales_Insight\Scripts\PreprocessingScript.py:215: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hospitalDfYearAndRemsimaSorted['Type'] = 'Hospitals'
# c:\Users\Josef\OneDrive\Skrivebord\ITU\3. semester\Big Data\Code\Indication-Insights\src\Sales_Insight\Scripts\PreprocessingScript.py:216: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PharmacyDfYearAndRemsimaSorted['Type'] = 'Pharmacies'
# c:\Users\Josef\OneDrive\Skrivebord\ITU\3. semester\Big Data\Code\Indication-Insights\src\Sales_Insight\Scripts\PreprocessingScript.py:226: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hospitalDfYearAndZesslySorted['Type'] = 'Hospitals'
# c:\Users\Josef\OneDrive\Skrivebord\ITU\3. semester\Big Data\Code\Indication-Insights\src\Sales_Insight\Scripts\PreprocessingScript.py:227: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PharmacyDfYearAndZesslySorted['Type'] = 'Pharmacies'

# %% [markdown]
# #### Draw stacked column chart of total sales of Stelara in hospitals and pharmacies btw 2010 and 2019

# %%
# Plot the stacked column chart
pivot_df_stelara.plot(kind='bar', stacked=True, figsize=(25, 10))
plt.xticks(rotation=90)
plt.title('Total Sales of Stelara in hospitals and pharmacies from 2010 to 2019')
plt.ylabel('Volume')
plt.xlabel('Year Month (after 2000) in Datetime')
plt.legend(title='Type')
plt.show()

# %% [markdown]
# #### Draw stacked column chart of total sales of Cimzia in hospitals and pharmacies btw 2010 and 2019

# %%
# Plot the stacked column chart
pivot_df_cimzia.plot(kind='bar', stacked=True, figsize=(25, 10))
plt.xticks(rotation=90)
plt.title('Total Sales of Cimzia in hospitals and pharmacies from 2010 to 2019')
plt.ylabel('Volume')
plt.xlabel('Year Month (after 2000)')
plt.legend(title='Type')
plt.show()

# %% [markdown]
# #### Draw stacked column chart of total sales of Inflectra in hospitals and pharmacies btw 2010 and 2019

# %%
# Plot the stacked column chart
pivot_df_inflectra.plot(kind='bar', stacked=True, figsize=(25, 10))
plt.xticks(rotation=90)
plt.title('Total Sales of Inflectra in hospitals and pharmacies from 2010 to 2019')
plt.ylabel('Volume')
plt.xlabel('Year Month (after 2000)')
plt.legend(title='Type')
plt.show()

# %% [markdown]
# #### Draw stacked column chart of total sales of Remicade in hospitals and pharmacies btw 2010 and 2019

# %%
# Plot the stacked column chart
pivot_df_remicade.plot(kind='bar', stacked=True, figsize=(25, 10))
plt.xticks(rotation=90)
plt.title('Total Sales of Remicade in hospitals and pharmacies from 2010 to 2019')
plt.ylabel('Volume')
plt.xlabel('Year Month (after 2000)')
plt.legend(title='Type')
plt.show()

# %% [markdown]
# #### Draw stacked column chart of total sales of Remsima in hospitals and pharmacies btw 2010 and 2019

# %%
# Plot the stacked column chart
pivot_df_remsima.plot(kind='bar', stacked=True, figsize=(25, 10))
plt.xticks(rotation=90)
plt.title('Total Sales of Remsima in hospitals and pharmacies from 2010 to 2019')
plt.ylabel('Volume')
plt.xlabel('Year Month (after 2000)')
plt.legend(title='Type')
plt.show()

# %% [markdown]
# #### Draw stacked column chart of total sales of Zessly in hospitals and pharmacies btw 2010 and 2019

# %%
# Plot the stacked column chart
pivot_df_zessly.plot(kind='bar', stacked=True, figsize=(25, 10))
plt.xticks(rotation=90)
plt.title('Total Sales of Zessly in hospitals and pharmacies from 2010 to 2019')
plt.ylabel('Volume')
plt.xlabel('Year Month (after 2000)')
plt.legend(title='Type')
plt.show()

# %% [markdown]
# #### Draw scatter, line, bubble, or combo plot to show relationship between sold stelara over time between 2010 and 2019 in central pharmacy

# %%
# Plot the median values in a line plot
sns.set_theme(style="whitegrid")
plt.figure(figsize=(30, 6))
sns.lineplot(x='Year Month (after 2000) in Datetime', y='Volume', data=meanValaues)
plt.xticks(rotation=90)
plt.title('Average Sales of Stelara in the central pharmacy by month btw 2010 and 2019')
plt.show()

# %% [markdown]
# #### Show correlation between Volume and other feeatures

# %%
m2.drop('Volume', axis=1).corrwith(m2.Volume).sort_values().plot(kind='barh', figsize=(15, 10))
# Out:
# <Axes: >
