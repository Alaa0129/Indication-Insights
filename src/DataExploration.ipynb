# %% [markdown]
# # Assignment 1 - Indication Insights

# %% [markdown]
# ### Data exploration

# %%
#import the relevant libraries
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# from sklearn.model_selection import train_test_split
# from sklearn.model_selection import cross_val_score
# from sklearn.preprocessing import StandardScaler
# from sklearn.tree import DecisionTreeClassifier
# from sklearn import metrics
# from sklearn.metrics import accuracy_score
# from sklearn.metrics import confusion_matrix
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 8
#       5 import seaborn as sns
#       6 import matplotlib.pyplot as plt
# ----> 8 from sklearn.model_selection import train_test_split
#       9 from sklearn.model_selection import cross_val_score
#      10 from sklearn.preprocessing import StandardScaler
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
#load our data
df = pd.read_csv("sales_insights_cleaned.csv", delimiter=",")

# %%
#check type
print("type of data: ", type(df))

#check dimensions
print("dimensions are: ", df.shape)
# Out:
# type of data:  <class 'pandas.core.frame.DataFrame'>
# dimensions are:  (7282, 22)

# %%
# check first 10 rows
pd.set_option('display.max_columns', None)
df.head(10)
# Out:
#         Account Description                 Size  Size Numeric  Strength (mg)  \
# 0  0030 Viborg Svane apotek  1  eng. spr. a 1 ml           1.0           90.0
# 1  0030 Viborg Svane apotek  1  eng. spr. a 1 ml           1.0           90.0
# 2  0030 Viborg Svane apotek  1  eng. spr. a 1 ml           1.0           90.0
# 3  0030 Viborg Svane apotek  1  eng. spr. a 1 ml           1.0           90.0
# 4  0030 Viborg Svane apotek  1  eng. spr. a 1 ml           1.0           90.0
# 5  0030 Viborg Svane apotek  1  eng. spr. a 1 ml           1.0           90.0
# 6  0030 Viborg Svane apotek  1  eng. spr. a 1 ml           1.0           90.0
# 7  0030 Viborg Svane apotek  1  eng. spr. a 1 ml           1.0           90.0
# 8  0030 Viborg Svane apotek  1  eng. spr. a 1 ml           1.0           90.0
# 9  0030 Viborg Svane apotek  1  eng. spr. a 1 ml           1.0           90.0
#
#   WHO ATC 5 Code  Volume     Value  Year Month (after 2000)  \
# 0        L04AC05     2.0  54149.24                   1201.0
# 1        L04AC05     1.0  27074.62                   1204.0
# 2        L04AC05     1.0  27074.62                   1207.0
# 3        L04AC05     2.0  54149.24                   1208.0
# 4        L04AC05     1.0  27074.62                   1209.0
# 5        L04AC05     1.0  27074.62                   1210.0
# 6        L04AC05     1.0  27074.62                   1301.0
# 7        L04AC05     1.0  27074.62                   1303.0
# 8        L04AC05     1.0  27074.62                   1304.0
# 9        L04AC05     1.0  26397.75                   1306.0
#
#    Year (after 2000)  Month  Region_Færøerne  Region_Hovedstaden  \
# 0               12.0    1.0            False               False
# 1               12.0    4.0            False               False
# 2               12.0    7.0            False               False
# 3               12.0    8.0            False               False
# 4               12.0    9.0            False               False
# 5               12.0   10.0            False               False
# 6               13.0    1.0            False               False
# 7               13.0    3.0            False               False
# 8               13.0    4.0            False               False
# 9               13.0    6.0            False               False
#
#    Region_Midtjylland  Region_Nordjylland  Region_Sjælland  Region_Syddanmark  \
# 0                True               False            False              False
# 1                True               False            False              False
# 2                True               False            False              False
# 3                True               False            False              False
# 4                True               False            False              False
# 5                True               False            False              False
# 6                True               False            False              False
# 7                True               False            False              False
# 8                True               False            False              False
# 9                True               False            False              False
#
#    Product_Cimzia  Product_Inflectra  Product_Remicade  Product_Remsima  \
# 0           False              False             False            False
# 1           False              False             False            False
# 2           False              False             False            False
# 3           False              False             False            False
# 4           False              False             False            False
# 5           False              False             False            False
# 6           False              False             False            False
# 7           False              False             False            False
# 8           False              False             False            False
# 9           False              False             False            False
#
#    Product_Stelara  Product_Zessly
# 0             True           False
# 1             True           False
# 2             True           False
# 3             True           False
# 4             True           False
# 5             True           False
# 6             True           False
# 7             True           False
# 8             True           False
# 9             True           False

# %%
# check last 10 rows
df.tail(10)
# Out:
#                 Account Description     Size  Size Numeric  Strength (mg)  \
# 7272  4398 Viborg Sygehus. apoteket   2 stk.           2.0          200.0
# 7273  4398 Viborg Sygehus. apoteket  1 htgl.           1.0          100.0
# 7274  4398 Viborg Sygehus. apoteket   2 stk.           2.0          200.0
# 7275  4398 Viborg Sygehus. apoteket  1 htgl.           1.0          100.0
# 7276  4398 Viborg Sygehus. apoteket   2 stk.           2.0          200.0
# 7277  4398 Viborg Sygehus. apoteket  1 htgl.           1.0          100.0
# 7278  4398 Viborg Sygehus. apoteket   2 stk.           2.0          200.0
# 7279  4398 Viborg Sygehus. apoteket  1 htgl.           1.0          100.0
# 7280  4398 Viborg Sygehus. apoteket   2 stk.           2.0          200.0
# 7281  4398 Viborg Sygehus. apoteket  1 htgl.           1.0          100.0
#
#      WHO ATC 5 Code  Volume       Value  Year Month (after 2000)  \
# 7272        L04AB05   100.0   788146.00                   1308.0
# 7273        L04AB02   296.0  1271802.48                   1308.0
# 7274        L04AB05    14.0   110340.44                   1309.0
# 7275        L04AB02   240.0  1031191.20                   1309.0
# 7276        L04AB05    51.0   401954.46                   1310.0
# 7277        L04AB02   472.0  2028009.36                   1310.0
# 7278        L04AB05    45.0   354665.70                   1311.0
# 7279        L04AB02   410.0  1761618.30                   1311.0
# 7280        L04AB05    52.0   409835.92                   1312.0
# 7281        L04AB02   292.0  1254615.96                   1312.0
#
#       Year (after 2000)  Month  Region_Færøerne  Region_Hovedstaden  \
# 7272               13.0    8.0            False               False
# 7273               13.0    8.0            False               False
# 7274               13.0    9.0            False               False
# 7275               13.0    9.0            False               False
# 7276               13.0   10.0            False               False
# 7277               13.0   10.0            False               False
# 7278               13.0   11.0            False               False
# 7279               13.0   11.0            False               False
# 7280               13.0   12.0            False               False
# 7281               13.0   12.0            False               False
#
#       Region_Midtjylland  Region_Nordjylland  Region_Sjælland  \
# 7272                True               False            False
# 7273                True               False            False
# 7274                True               False            False
# 7275                True               False            False
# 7276                True               False            False
# 7277                True               False            False
# 7278                True               False            False
# 7279                True               False            False
# 7280                True               False            False
# 7281                True               False            False
#
#       Region_Syddanmark  Product_Cimzia  Product_Inflectra  Product_Remicade  \
# 7272              False            True              False             False
# 7273              False           False              False              True
# 7274              False            True              False             False
# 7275              False           False              False              True
# 7276              False            True              False             False
# 7277              False           False              False              True
# 7278              False            True              False             False
# 7279              False           False              False              True
# 7280              False            True              False             False
# 7281              False           False              False              True
#
#       Product_Remsima  Product_Stelara  Product_Zessly
# 7272            False            False           False
# 7273            False            False           False
# 7274            False            False           False
# 7275            False            False           False
# 7276            False            False           False
# 7277            False            False           False
# 7278            False            False           False
# 7279            False            False           False
# 7280            False            False           False
# 7281            False            False           False

# %%
# get column labels
df.columns
# Out:
# Index(['Account Description', 'Size', 'Size Numeric', 'Strength (mg)',
#        'WHO ATC 5 Code', 'Volume', 'Value', 'Year Month (after 2000)',
#        'Year (after 2000)', 'Month', 'Region_Færøerne', 'Region_Hovedstaden',
#        'Region_Midtjylland', 'Region_Nordjylland', 'Region_Sjælland',
#        'Region_Syddanmark', 'Product_Cimzia', 'Product_Inflectra',
#        'Product_Remicade', 'Product_Remsima', 'Product_Stelara',
#        'Product_Zessly'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7282 entries, 0 to 7281
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Account Description      7282 non-null   object
#  1   Size                     7282 non-null   object
#  2   Size Numeric             7282 non-null   float64
#  3   Strength (mg)            7282 non-null   float64
#  4   WHO ATC 5 Code           7282 non-null   object
#  5   Volume                   7282 non-null   float64
#  6   Value                    7282 non-null   float64
#  7   Year Month (after 2000)  7282 non-null   float64
#  8   Year (after 2000)        7282 non-null   float64
#  9   Month                    7282 non-null   float64
#  10  Region_Færøerne          7282 non-null   bool
#  11  Region_Hovedstaden       7282 non-null   bool
#  12  Region_Midtjylland       7282 non-null   bool
#  13  Region_Nordjylland       7282 non-null   bool
#  14  Region_Sjælland          7282 non-null   bool
#  15  Region_Syddanmark        7282 non-null   bool
#  16  Product_Cimzia           7282 non-null   bool
#  17  Product_Inflectra        7282 non-null   bool
#  18  Product_Remicade         7282 non-null   bool
#  19  Product_Remsima          7282 non-null   bool
#  20  Product_Stelara          7282 non-null   bool
#  21  Product_Zessly           7282 non-null   bool
# dtypes: bool(12), float64(7), object(3)
# memory usage: 654.4+ KB

# %%
# get quick statistical summary of our dataset
df.describe()
# Out:
#        Size Numeric  Strength (mg)        Volume         Value  \
# count   7282.000000    7282.000000   7282.000000  7.282000e+03
# mean       5.226586     101.928728    169.297583  7.922291e+05
# std       19.514250      51.570362    536.090108  2.096975e+06
# min        1.000000      45.000000     -5.000000 -5.524500e+04
# 25%        1.000000      45.000000      1.000000  2.639775e+04
# 50%        1.000000     100.000000     14.000000  1.553120e+05
# 75%        1.000000     100.000000     90.000000  6.949209e+05
# max      100.000000     200.000000  12200.000000  5.303520e+07
#
#        Year Month (after 2000)  Year (after 2000)        Month
# count              7282.000000        7282.000000  7282.000000
# mean               1544.943697          15.384647     6.478989
# std                 285.322369           2.856539     3.428018
# min                1001.000000          10.000000     1.000000
# 25%                1307.000000          13.000000     4.000000
# 50%                1602.000000          16.000000     6.000000
# 75%                1804.000000          18.000000     9.000000
# max                2006.000000          20.000000    12.000000

# %%
# `corr`: The computed correlation matrix
# Method = pearson
# Numeric values only. A correlation cannot take into account qualitative data unless they are transformed. More on that in week 7
corr = df.corr(method='pearson', numeric_only=True)
corr
# Out:
#                          Size Numeric  Strength (mg)    Volume     Value  \
# Size Numeric                 1.000000       0.009777  0.056197  0.061038
# Strength (mg)                0.009777       1.000000  0.025191  0.037225
# Volume                       0.056197       0.025191  1.000000  0.926460
# Value                        0.061038       0.037225  0.926460  1.000000
# Year Month (after 2000)     -0.366029      -0.035067  0.022540  0.040911
# Year (after 2000)           -0.364885      -0.034937  0.022072  0.040341
# Month                       -0.059878      -0.007452  0.036764  0.043504
# Region_Færøerne              0.053265       0.103416 -0.053125 -0.062229
# Region_Hovedstaden          -0.027521      -0.013788  0.231416  0.294694
# Region_Midtjylland          -0.003113      -0.106003  0.035478  0.042085
# Region_Nordjylland          -0.045688      -0.082211 -0.037784 -0.055842
# Region_Sjælland              0.039581      -0.029469 -0.066843 -0.076974
# Region_Syddanmark           -0.003590       0.140313 -0.069605 -0.089903
# Product_Cimzia              -0.077446       0.890732 -0.092104 -0.068889
# Product_Inflectra           -0.036119      -0.006237  0.332220  0.298815
# Product_Remicade             0.403618      -0.018866  0.114243  0.111113
# Product_Remsima             -0.053044      -0.009159  0.255386  0.116830
# Product_Stelara             -0.220931      -0.661185 -0.304300 -0.272392
# Product_Zessly              -0.026211      -0.005835  0.188181  0.278938
#
#                          Year Month (after 2000)  Year (after 2000)     Month  \
# Size Numeric                           -0.366029          -0.364885 -0.059878
# Strength (mg)                          -0.035067          -0.034937 -0.007452
# Volume                                  0.022540           0.022072  0.036764
# Value                                   0.040911           0.040341  0.043504
# Year Month (after 2000)                 1.000000           0.999929 -0.090754
# Year (after 2000)                       0.999929           1.000000 -0.102649
# Month                                  -0.090754          -0.102649  1.000000
# Region_Færøerne                         0.013572           0.013610 -0.004535
# Region_Hovedstaden                     -0.005950          -0.006006  0.005247
# Region_Midtjylland                     -0.064855          -0.064860  0.006738
# Region_Nordjylland                      0.098470           0.098390 -0.002873
# Region_Sjælland                        -0.069079          -0.068934 -0.005404
# Region_Syddanmark                       0.041543           0.041497 -0.000209
# Product_Cimzia                         -0.077499          -0.077465  0.004644
# Product_Inflectra                       0.153311           0.152977  0.012998
# Product_Remicade                       -0.268551          -0.267956 -0.023560
# Product_Remsima                         0.104925           0.104781  0.001848
# Product_Stelara                         0.110749           0.110484  0.011341
# Product_Zessly                          0.218500           0.218287 -0.003384
#
#                          Region_Færøerne  Region_Hovedstaden  \
# Size Numeric                    0.053265           -0.027521
# Strength (mg)                   0.103416           -0.013788
# Volume                         -0.053125            0.231416
# Value                          -0.062229            0.294694
# Year Month (after 2000)         0.013572           -0.005950
# Year (after 2000)               0.013610           -0.006006
# Month                          -0.004535            0.005247
# Region_Færøerne                 1.000000           -0.067592
# Region_Hovedstaden             -0.067592            1.000000
# Region_Midtjylland             -0.096455           -0.159478
# Region_Nordjylland             -0.079638           -0.131673
# Region_Sjælland                -0.107335           -0.177467
# Region_Syddanmark              -0.138909           -0.229672
# Product_Cimzia                  0.098561           -0.011514
# Product_Inflectra              -0.033715           -0.002260
# Product_Remicade                0.093165           -0.024385
# Product_Remsima                -0.046454            0.028831
# Product_Stelara                -0.108649            0.018054
# Product_Zessly                 -0.031541           -0.007168
#
#                          Region_Midtjylland  Region_Nordjylland  \
# Size Numeric                      -0.003113           -0.045688
# Strength (mg)                     -0.106003           -0.082211
# Volume                             0.035478           -0.037784
# Value                              0.042085           -0.055842
# Year Month (after 2000)           -0.064855            0.098470
# Year (after 2000)                 -0.064860            0.098390
# Month                              0.006738           -0.002873
# Region_Færøerne                   -0.096455           -0.079638
# Region_Hovedstaden                -0.159478           -0.131673
# Region_Midtjylland                 1.000000           -0.187900
# Region_Nordjylland                -0.187900            1.000000
# Region_Sjælland                   -0.253250           -0.209095
# Region_Syddanmark                 -0.327747           -0.270604
# Product_Cimzia                    -0.065190           -0.056555
# Product_Inflectra                 -0.040342           -0.023478
# Product_Remicade                  -0.045539           -0.075485
# Product_Remsima                   -0.052585           -0.031958
# Product_Stelara                    0.134769            0.130779
# Product_Zessly                    -0.034973           -0.013843
#
#                          Region_Sjælland  Region_Syddanmark  Product_Cimzia  \
# Size Numeric                    0.039581          -0.003590       -0.077446
# Strength (mg)                  -0.029469           0.140313        0.890732
# Volume                         -0.066843          -0.069605       -0.092104
# Value                          -0.076974          -0.089903       -0.068889
# Year Month (after 2000)        -0.069079           0.041543       -0.077499
# Year (after 2000)              -0.068934           0.041497       -0.077465
# Month                          -0.005404          -0.000209        0.004644
# Region_Færøerne                -0.107335          -0.138909        0.098561
# Region_Hovedstaden             -0.177467          -0.229672       -0.011514
# Region_Midtjylland             -0.253250          -0.327747       -0.065190
# Region_Nordjylland             -0.209095          -0.270604       -0.056555
# Region_Sjælland                 1.000000          -0.364717       -0.044038
# Region_Syddanmark              -0.364717           1.000000        0.101072
# Product_Cimzia                 -0.044038           0.101072        1.000000
# Product_Inflectra               0.021844           0.046847       -0.078098
# Product_Remicade                0.041454           0.033216       -0.236246
# Product_Remsima                 0.014953           0.054623       -0.114695
# Product_Stelara                -0.021444          -0.155140       -0.477711
# Product_Zessly                  0.026051           0.033862       -0.073063
#
#                          Product_Inflectra  Product_Remicade  Product_Remsima  \
# Size Numeric                     -0.036119          0.403618        -0.053044
# Strength (mg)                    -0.006237         -0.018866        -0.009159
# Volume                            0.332220          0.114243         0.255386
# Value                             0.298815          0.111113         0.116830
# Year Month (after 2000)           0.153311         -0.268551         0.104925
# Year (after 2000)                 0.152977         -0.267956         0.104781
# Month                             0.012998         -0.023560         0.001848
# Region_Færøerne                  -0.033715          0.093165        -0.046454
# Region_Hovedstaden               -0.002260         -0.024385         0.028831
# Region_Midtjylland               -0.040342         -0.045539        -0.052585
# Region_Nordjylland               -0.023478         -0.075485        -0.031958
# Region_Sjælland                   0.021844          0.041454         0.014953
# Region_Syddanmark                 0.046847          0.033216         0.054623
# Product_Cimzia                   -0.078098         -0.236246        -0.114695
# Product_Inflectra                 1.000000         -0.084111        -0.040835
# Product_Remicade                 -0.084111          1.000000        -0.123526
# Product_Remsima                  -0.040835         -0.123526         1.000000
# Product_Stelara                  -0.170080         -0.514492        -0.249781
# Product_Zessly                   -0.026012         -0.078688        -0.038202
#
#                          Product_Stelara  Product_Zessly
# Size Numeric                   -0.220931       -0.026211
# Strength (mg)                  -0.661185       -0.005835
# Volume                         -0.304300        0.188181
# Value                          -0.272392        0.278938
# Year Month (after 2000)         0.110749        0.218500
# Year (after 2000)               0.110484        0.218287
# Month                           0.011341       -0.003384
# Region_Færøerne                -0.108649       -0.031541
# Region_Hovedstaden              0.018054       -0.007168
# Region_Midtjylland              0.134769       -0.034973
# Region_Nordjylland              0.130779       -0.013843
# Region_Sjælland                -0.021444        0.026051
# Region_Syddanmark              -0.155140        0.033862
# Product_Cimzia                 -0.477711       -0.073063
# Product_Inflectra              -0.170080       -0.026012
# Product_Remicade               -0.514492       -0.078688
# Product_Remsima                -0.249781       -0.038202
# Product_Stelara                 1.000000       -0.159114
# Product_Zessly                 -0.159114        1.000000

# %%
# We create a new figure (fig) and axis (ax) with a specified size.
fig, ax = plt.subplots(figsize=(20,20)) # Adjust the figsize values to change the size of each cell in the heatmap.

# - `xticklabels` & `yticklabels`: Use the columns of the correlation matrix for labeling the x and y axis respectively.
#   blue represents positive correlations and red represents negative correlations.
sns.heatmap(corr, vmin= -1, vmax=1, xticklabels=corr.columns, yticklabels=corr.columns, cmap='RdBu_r', annot=True, linewidth=0.5, ax=ax)
# Out:
# <Axes: >

# %%
size_range = df["Size"].unique()
print("Unique values in the 'Size' column:", size_range)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 size_range = df["Size"].unique()
#       2 print("Unique values in the 'Size' column:", size_range)
#
# NameError: name 'df' is not defined
